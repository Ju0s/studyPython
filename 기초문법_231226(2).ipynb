# %% [markdown]
# # 새로운 파일

# %%
1+1  # Ctrl + Enter: 실행
# Out:
# 2

# %%
# Alt + Enter: 셀 실행 후 다음 셀 삽입
# Shift + Enter: 셀 실행 후 다음 셀 선택

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive
