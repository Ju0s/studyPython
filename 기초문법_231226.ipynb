# %% [markdown]
# # Section 1
# - 멀티캠퍼스 첫 수업

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ## Chapter 1. 구글 코랩 수업
# - 23.12.26

# %%
a = 1
b = 2

# %% [markdown]
# # Section 2 ~~
# - ~~

# %%
1 == 1
# Out:
# True

# %% [markdown]
# ## Chapter 2 ~~
# - ~~

# %%
3 != 3
# Out:
# False

# %% [markdown]
# ### hi

# %%
print("hi")
# Out:
# hi

# %% [markdown]
# # 파이썬 확장명
# - .ipynb: 데이터 분석가
# - .py: 웹개발, 대시보드 진행 시
